# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import openai
import urllib.request
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow

# %%
openai.api_key = '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'

# %%
img_response = openai.Image.create(
    prompt = 'a loft bedroom with a white bed next to a nightstand. there is a fish tank beside the bed.',
    n = 1,
    size = '512x512' # 256x256 512x512 1024x1024
)

# %%
img_response
# Out:
# <OpenAIObject at 0x7f7b20d58810> JSON: {
#   "created": 1672149203,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-He4XkHzQmFeGZfyJSPgvlMqH/user-Xlm9v7FywzEt5hI6H3wPobtm/img-G7dLzDkGhAtdgH9JqJwosZfX.png?st=2022-12-27T12%3A53%3A23Z&se=2022-12-27T14%3A53%3A23Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2022-12-27T08%3A45%3A02Z&ske=2022-12-28T08%3A45%3A02Z&sks=b&skv=2021-08-06&sig=jjjUDqA9yz3VoKAivWR75VTyEnpNqVyeLGzslfNsr3U%3D"
#     }
#   ]
# }

# %%
img_response['data'][0]['url']
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-He4XkHzQmFeGZfyJSPgvlMqH/user-Xlm9v7FywzEt5hI6H3wPobtm/img-G7dLzDkGhAtdgH9JqJwosZfX.png?st=2022-12-27T12%3A53%3A23Z&se=2022-12-27T14%3A53%3A23Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2022-12-27T08%3A45%3A02Z&ske=2022-12-28T08%3A45%3A02Z&sks=b&skv=2021-08-06&sig=jjjUDqA9yz3VoKAivWR75VTyEnpNqVyeLGzslfNsr3U%3D'

# %%
img_url = img_response['data'][0]['url']

# %%
urllib.request.urlretrieve(img_url, 'img.png')
# Out:
# ('img.png', <http.client.HTTPMessage at 0x7f7b20d5cf10>)

# %%
img = cv2.imread('img.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F7B20D5C9D0>
